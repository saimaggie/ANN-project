# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model

# %%
#Read excel file
df=pd.read_excel(r"C:\Users\Dell\Desktop\Cost_prediction_fl.xlsx")
df
# Out:
#        Area   Earthwork excavation  Back filling   Earth from outside    \
# 0     786.00                 914353         442976               407855
# 1    5443.52               17849814       7,47,441            50,02,371
# 2    7350.67              212124372         533333               856788
# 3    1288.89                2337862         356565               189160
# 4    1476.67                 545356         310826               367724
# 5    2088.00                1051084         816554               873452
# 6    3143.00                4055461         556000               512122
# 7     656.00                 105130         123000               112000
# 8    1020.00                 630780         392000               224000
# 9    1176.00                 814500         317143               123232
# 10   1667.67                 588711         452323               355433
# 11   2566.00                1000000         328484               515789
# ...

# %%
df.columns
# Out:
# Index(['Area ', 'Earthwork excavation ', 'Back filling  ',
#        'Earth from outside  ', 'PCC works', 'RCC works', 'Masonry for infills',
#        'Steel in tons', 'Cost'],
#       dtype='object')

# %%
df_=df.replace('[^\d.]','',regex=True).astype(float)
df_
# Out:
#        Area   Earthwork excavation   Back filling    Earth from outside    \
# 0     786.00               914353.0        442976.0              407855.0
# 1    5443.52             17849814.0        747441.0             5002371.0
# 2    7350.67            212124372.0        533333.0              856788.0
# 3    1288.89              2337862.0        356565.0              189160.0
# 4    1476.67               545356.0        310826.0              367724.0
# 5    2088.00              1051084.0        816554.0              873452.0
# 6    3143.00              4055461.0        556000.0              512122.0
# 7     656.00               105130.0        123000.0              112000.0
# 8    1020.00               630780.0        392000.0              224000.0
# 9    1176.00               814500.0        317143.0              123232.0
# 10   1667.67               588711.0        452323.0              355433.0
# 11   2566.00              1000000.0        328484.0              515789.0
# ...

# %%
X=df_[['Area ', 'Earthwork excavation ', 'Back filling  ',
       'Earth from outside  ', 'PCC works', 'RCC works', 'Masonry for infills',
       'Steel in tons']]
y=df_[['Cost']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=2)
#It creates two sets of data one is trained set and test set

# %%
X_train
# Out:
#        Area   Earthwork excavation   Back filling    Earth from outside    \
# 6    3143.00              4055461.0        556000.0              512122.0
# 23   6382.00               375740.0         75986.0              502583.0
# 9    1176.00               814500.0        317143.0              123232.0
# 3    1288.89              2337862.0        356565.0              189160.0
# 16     69.00                45995.0          9718.0                8005.0
# 12   9000.00             10537138.0       2082578.0             2083578.0
# 22  10522.00             17916840.0        862331.0             2896520.0
# 4    1476.67               545356.0        310826.0              367724.0
# 10   1667.67               588711.0        452323.0              355433.0
# 5    2088.00              1051084.0        816554.0              873452.0
# 19    165.00                10833.0          2101.0               14490.0
# 1    5443.52             17849814.0        747441.0             5002371.0
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 
print("Training completed")
# Out:
# Training completed

# %%
regressor.coef_
# Out:
# array([[ 1.38754339e+04, -1.13366535e-02, -1.85715450e+00,
#         -9.27678481e-02,  1.95698989e-01, -7.78023895e-03,
#         -1.64702574e-01, -3.68077327e-02]])

# %%
regressor.intercept_
# Out:
# array([1318227.51080742])

# %%
y_pred=regressor.predict(X_test)

# %%
#Comparing actual vs predicted
y_test
# Out:
#            Cost
# 14  130000000.0
# 0    12625719.0
# 17   10710000.0

# %%
y_pred
# Out:
# array([[1.31999365e+08],
#        [1.09227817e+07],
#        [1.11521188e+07]])

# %%
regressor.predict([[7350.67,212124372.0,533333.0,856788.0,8332215.00,30240545.0,32878584.00,6370000.0]])
# Out:
# array([[95582893.58919711]])

# %%
regressor.predict([[7000.0,212124372.0,533333.0,856788.0,8332215.00,30240545.0,32878584.00,6370000.0]])
# Out:
# array([[90717195.16894183]])

# %%
regressor.predict([[1288.89,2337862.0,356565.0,189160.0,3131136.00,5777524.0,5661366.00,3965000.0]])
# Out:
# array([[17985313.1922567]])

# %%
regressor.predict([[786.00,914353.0,442976.0,407855.0,300622.84,7764888.0,2053181.75,2470000.0]])
# Out:
# array([[10922781.66595965]])

# %%
regressor.predict([[10522.00,17916840.0,862331.0,2896520.0,4555407.00,59727401.0,50827501.00,7995000.0]])
# Out:
# array([[1.37003338e+08]])

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

# %%
score
# Out:
# 0.9992403283618988
